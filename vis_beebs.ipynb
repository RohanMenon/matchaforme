# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ratings = pd.read_csv('/Users/rohanmenon/Downloads/SIXTdsTask/matcha.csv')

# %%
ratings.describe()
# Out:
#           rating      price
# count  19.000000  19.000000
# mean    6.421053   6.539474
# std     2.662826   1.189956
# min     0.000000   4.750000
# 25%     4.750000   5.575000
# 50%     7.000000   6.250000
# 75%     8.250000   7.575000
# max    10.000000   8.750000

# %%
ordered_price_ratings = ratings.sort_values(by='price', ascending=True)

# %%
sns.barplot(x='price', y='name', data=ordered_price_ratings)
# Out:
# <Axes: xlabel='price', ylabel='name'>

# %%
ordered_ratings = ratings.sort_values(by='rating', ascending=True)

# %%
sns.barplot(x='rating', y='name', data=ordered_ratings)
# Out:
# <Axes: xlabel='rating', ylabel='name'>

# %%
sns.barplot(x='price', y='name', data=ratings)
# Out:
# <Axes: xlabel='price', ylabel='name'>

# %%
sub_df = ratings[['rating', 'price']]

# %%
sub_df.corr()
# Out:
#           rating     price
# rating  1.000000  0.433224
# price   0.433224  1.000000

# %%
val = ratings['rating']
# unique_ratings = ratings.groupby('name').mean()

# unique_ratings.plot(kind='barh')

# %%
rate = ratings['rating'].astype('category')
rate_count = rate.groupby(rate).apply(lambda x: x.count())

# %%
sns.barplot(x=rate_count.index, y=rate_count.values)
plt.yticks(range(0, int(rate_count.max()*2)+1, 2))
plt.xlabel('Rating')
plt.ylabel('Rating Count')
plt.title('Distribution of Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution of Ratings')
